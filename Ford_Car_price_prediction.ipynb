# %%
pwd
# Out:
# 'C:\\Users\\manga\\anaconda3'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('ford.csv')
df
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17960   Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %%
df.shape
# Out:
# (17965, 9)

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.nunique()
# Out:
# model              23
# year               23
# price            3511
# transmission        3
# mileage         13528
# fuelType            5
# tax                35
# mpg                90
# engineSize         16
# dtype: int64

# %%
df.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17965.000000  17965.000000   17965.000000  17965.000000  17965.000000
# mean    2016.866574  12279.756415   23363.630504    113.334539     57.906991
# std        2.050346   4741.382606   19472.114690     62.010438     10.125977
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18243.000000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31064.000000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17965.000000
# mean       1.350827
# std        0.432371
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %% [markdown]
# # Bivariate analysis

# %%
sns.scatterplot(x='model',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='model', ylabel='price'>

# %%
sns.scatterplot(x='transmission',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='price'>

# %%
sns.scatterplot(x='fuelType',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='fuelType', ylabel='price'>

# %%
sns.scatterplot(x='tax',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='tax', ylabel='price'>

# %%
sns.scatterplot(x='mpg',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='price'>

# %%
sns.scatterplot(x='engineSize',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='engineSize', ylabel='price'>

# %%
sns.barplot(x='model',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='model', ylabel='price'>

# %% [markdown]
# # Multivariate analysis

# %%
sns.pairplot(df);
sns
# Out:
# <module 'seaborn' from 'C:\\Users\\manga\\anaconda3\\lib\\site-packages\\seaborn\\__init__.py'>

# %%
df['fuelType'].value_counts()
# Out:
# Petrol      12178
# Diesel       5762
# Hybrid         22
# Electric        2
# Other           1
# Name: fuelType, dtype: int64

# %% [markdown]
# # Label Encoding for Categorical Values

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['model']= le.fit_transform(df['model'])
df
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0          5  2017  12000    Automatic    15944   Petrol  150  57.7
# 1          6  2018  14000       Manual     9083   Petrol  150  57.7
# 2          6  2017  13000       Manual    12456   Petrol  150  57.7
# 3          5  2019  17500       Manual    10460   Petrol  145  40.3
# 4          5  2019  16500    Automatic     1482   Petrol  145  48.7
# ...      ...   ...    ...          ...      ...      ...  ...   ...
# 17960      5  2016   7999       Manual    31348   Petrol  125  54.3
# 17961      0  2017   8999       Manual    16700   Petrol  150  47.1
# 17962      0  2014   7499       Manual    40700   Petrol   30  57.7
# 17963      6  2015   9999       Manual     7010   Diesel   20  67.3
# 17964     11  2018   8299       Manual     5007   Petrol  145  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# ...

# %%
df['transmission']= le.fit_transform(df['transmission'])
df
# Out:
#        model  year  price  transmission  mileage fuelType  tax   mpg  \
# 0          5  2017  12000             0    15944   Petrol  150  57.7
# 1          6  2018  14000             1     9083   Petrol  150  57.7
# 2          6  2017  13000             1    12456   Petrol  150  57.7
# 3          5  2019  17500             1    10460   Petrol  145  40.3
# 4          5  2019  16500             0     1482   Petrol  145  48.7
# ...      ...   ...    ...           ...      ...      ...  ...   ...
# 17960      5  2016   7999             1    31348   Petrol  125  54.3
# 17961      0  2017   8999             1    16700   Petrol  150  47.1
# 17962      0  2014   7499             1    40700   Petrol   30  57.7
# 17963      6  2015   9999             1     7010   Diesel   20  67.3
# 17964     11  2018   8299             1     5007   Petrol  145  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# ...

# %%
df['fuelType']= le.fit_transform(df['fuelType'])
df
# Out:
#        model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 0          5  2017  12000             0    15944         4  150  57.7
# 1          6  2018  14000             1     9083         4  150  57.7
# 2          6  2017  13000             1    12456         4  150  57.7
# 3          5  2019  17500             1    10460         4  145  40.3
# 4          5  2019  16500             0     1482         4  145  48.7
# ...      ...   ...    ...           ...      ...       ...  ...   ...
# 17960      5  2016   7999             1    31348         4  125  54.3
# 17961      0  2017   8999             1    16700         4  150  47.1
# 17962      0  2014   7499             1    40700         4   30  57.7
# 17963      6  2015   9999             1     7010         0   20  67.3
# 17964     11  2018   8299             1     5007         4  145  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %% [markdown]
# # correlation

# %%
corr=df.corr()
corr
# Out:
#                  model      year     price  transmission   mileage  fuelType  \
# model         1.000000  0.030460  0.315072     -0.063433  0.079013 -0.389039
# year          0.030460  1.000000  0.635994     -0.017119 -0.707899  0.087992
# price         0.315072  0.635994  1.000000     -0.058033 -0.530727 -0.202829
# transmission -0.063433 -0.017119 -0.058033      1.000000  0.016651 -0.005118
# mileage       0.079013 -0.707899 -0.530727      0.016651  1.000000 -0.257531
# fuelType     -0.389039  0.087992 -0.202829     -0.005118 -0.257531  1.000000
# tax           0.183914  0.298457  0.406821     -0.053305 -0.260550  0.129652
# mpg          -0.222055 -0.022969 -0.346427      0.056084  0.120077 -0.297799
# engineSize    0.500782 -0.137358  0.411156     -0.026485  0.215001 -0.644609
#
#                    tax       mpg  engineSize
# model         0.183914 -0.222055    0.500782
# year          0.298457 -0.022969   -0.137358
# price         0.406821 -0.346427    0.411156
# ...

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(labels=['price'],axis=1),df['price'],test_size=0.2,random_state=0)

# %% [markdown]
# # Linear Regression

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
model=reg.fit(X_train,y_train)

# %%
model.coef_
# Out:
# array([ 3.12103376e+01,  1.13421745e+03, -2.94236611e+02, -6.48149673e-02,
#        -3.51272956e+02,  1.22811727e+00, -1.08778189e+02,  4.01898275e+03])

# %%
model.intercept_
# Out:
# -2272017.494846151

# %%
predictions=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predictions)
# Out:
# 0.7435349345131506

# %%
train_pred=model.predict(X_train)
r2_score(y_train,train_pred)
# Out:
# 0.7322692099545092

# %% [raw]
# # no overfitting issue , it gives the output quite accurately

# %% [markdown]
# # Lasso regression

# %%
from sklearn.linear_model import Lasso
model=Lasso(alpha=.00001, max_iter=10000,tol=0.01)
model.fit(X_train,y_train)
predictions=model.predict(X_test)
r2_score(y_test,predictions)
# Out:
# 0.7435349342811829

# %%
train_pred=model.predict(X_train)
r2_score(y_train,train_pred)
# Out:
# 0.7322692099545138

# %% [raw]
# # no overfitting issue , it gives the output quite accurately

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import cross_val_score
rf=RandomForestRegressor(max_depth=10,n_estimators=30,min_samples_split=12)
model=rf.fit(X_train,y_train)
predictions=model.predict(X_test)
r2_score(y_test,predictions)
# Out:
# 0.9250803397353843

# %%
train_pred=rf.predict(X_train)
r2_score(y_train,train_pred)
# Out:
# 0.9410452041558476

# %% [raw]
# # gives acurate results with almost 90% acuracy
